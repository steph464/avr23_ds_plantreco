# %%
#pip install tensorflow

# %%
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt


data = pd.read_csv('data_no_bg.csv')

# Paramètres du modèle

input_shape = (256, 256, 3)  
num_classes = len(data.nom_maladie.unique())

data.loc[data['malade'] == False, 'nom_maladie'] = 'healthy'

data.head()
# Out:
#                                             img_path espece  malade  \
# 0  C:\Users\aissa\Desktop\Projet\dataset_remove_b...  Apple    True
# 1  C:\Users\aissa\Desktop\Projet\dataset_remove_b...  Apple    True
# 2  C:\Users\aissa\Desktop\Projet\dataset_remove_b...  Apple    True
# 3  C:\Users\aissa\Desktop\Projet\dataset_remove_b...  Apple    True
# 4  C:\Users\aissa\Desktop\Projet\dataset_remove_b...  Apple    True
#
#   nom_maladie
# 0  Apple_scab
# 1  Apple_scab
# 2  Apple_scab
# 3  Apple_scab
# 4  Apple_scab

# %% [markdown]
# ### Division du jeu de données en 10 dataframes équilibrés

# %%
from sklearn.model_selection import StratifiedShuffleSplit

X = data.drop(['espece', 'malade', 'nom_maladie'], axis=1)
y = data['nom_maladie']

dfs = []
sss = StratifiedShuffleSplit(n_splits=10, test_size=0.9)
for train_index, _ in sss.split(X, y):
    df = pd.concat([X.iloc[train_index].reset_index(drop=True), y.iloc[train_index].reset_index(drop=True)], axis=1)
    dfs.append(df)

fig, axs = plt.subplots(5, 2, figsize=(12, 18))

for i, df in enumerate(dfs):
    value_counts = df['nom_maladie'].value_counts()
    
    row = i // 2
    col = i % 2
    
    axs[row, col].bar(value_counts.index, value_counts.values)
    axs[row, col].set_title(f"Distribution - DataFrame {i+1}")
    axs[row, col].set_xlabel("nom_maladie")
    axs[row, col].set_ylabel("Nombre d'images")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Prétraitement des données

# %%
data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generators = []
validation_generators = []

for i in range(10):
    data_i = dfs[i]  
    
    train_generator = data_generator.flow_from_dataframe(
        dataframe=data_i,
        x_col="img_path",
        y_col="nom_maladie",
        target_size=input_shape[:2],
        batch_size=64,
        class_mode='categorical',
        subset='training'
    )
    train_generators.append(train_generator)
    
    validation_generator = data_generator.flow_from_dataframe(
        dataframe=data_i,
        x_col="img_path",
        y_col="nom_maladie",
        target_size=input_shape[:2],
        batch_size=64,
        class_mode='categorical',
        subset='validation'
    )
    validation_generators.append(validation_generator)
# Out:
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.
# Found 5624 validated image filenames belonging to 21 classes.
# Found 1405 validated image filenames belonging to 21 classes.

# %% [markdown]
# ### Modèle

# %%
# VGG16

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Freezing

for layer in base_model.layers:
    layer.trainable = False

# Nouvelles couches 

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
predictions = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.models.Model(inputs=base_model.input, outputs=predictions)

# Compilation

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 29s 0us/step

# %%
checkpoint_callback = ModelCheckpoint(
    'tf_VGG16_id_nom_maladie.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Boucle pour entraîner le modèle pour chaque data_i

for i in range(5):
    train_generator_i = train_generators[i]
    validation_generator_i = validation_generators[i]

    print(f"Entraînement du modèle pour data_{i+1} :")

    history = model.fit(
        train_generator_i,
        steps_per_epoch=train_generator_i.samples // train_generator_i.batch_size,
        epochs=8,
        validation_data=validation_generator_i,
        validation_steps=validation_generator_i.samples // validation_generator_i.batch_size,
        callbacks=[checkpoint_callback]
    )

    print(f"Fin de l'entraînement du modèle pour data_{i+1}.")
    print()
# Out:
# Entraînement du modèle pour data_1 :
# Epoch 1/8
# 87/87 [==============================] - ETA: 0s - loss: 2.4200 - accuracy: 0.3309
# Epoch 1: val_accuracy improved from -inf to 0.34226, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 933s 11s/step - loss: 2.4200 - accuracy: 0.3309 - val_loss: 2.2146 - val_accuracy: 0.3423
# Epoch 2/8
# 87/87 [==============================] - ETA: 0s - loss: 1.9575 - accuracy: 0.4126
# Epoch 2: val_accuracy improved from 0.34226 to 0.45759, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 932s 11s/step - loss: 1.9575 - accuracy: 0.4126 - val_loss: 1.8050 - val_accuracy: 0.4576
# Epoch 3/8
# 87/87 [==============================] - ETA: 0s - loss: 1.5957 - accuracy: 0.5187
# Epoch 3: val_accuracy improved from 0.45759 to 0.54539, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 936s 11s/step - loss: 1.5957 - accuracy: 0.5187 - val_loss: 1.5250 - val_accuracy: 0.5454
# Epoch 4/8
# 87/87 [==============================] - ETA: 0s - loss: 1.3482 - accuracy: 0.6029
# Epoch 4: val_accuracy improved from 0.54539 to 0.59673, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 933s 11s/step - loss: 1.3482 - accuracy: 0.6029 - val_loss: 1.3233 - val_accuracy: 0.5967
# Epoch 5/8
# 87/87 [==============================] - ETA: 0s - loss: 1.1825 - accuracy: 0.6450
# Epoch 5: val_accuracy improved from 0.59673 to 0.62277, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 936s 11s/step - loss: 1.1825 - accuracy: 0.6450 - val_loss: 1.2168 - val_accuracy: 0.6228
# Epoch 6/8
# 87/87 [==============================] - ETA: 0s - loss: 1.0647 - accuracy: 0.6845
# Epoch 6: val_accuracy improved from 0.62277 to 0.65848, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 933s 11s/step - loss: 1.0647 - accuracy: 0.6845 - val_loss: 1.1055 - val_accuracy: 0.6585
# Epoch 7/8
# 87/87 [==============================] - ETA: 0s - loss: 0.9778 - accuracy: 0.7022
# Epoch 7: val_accuracy improved from 0.65848 to 0.68229, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 934s 11s/step - loss: 0.9778 - accuracy: 0.7022 - val_loss: 1.0469 - val_accuracy: 0.6823
# Epoch 8/8
# 87/87 [==============================] - ETA: 0s - loss: 0.9039 - accuracy: 0.7309
# Epoch 8: val_accuracy improved from 0.68229 to 0.68378, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 932s 11s/step - loss: 0.9039 - accuracy: 0.7309 - val_loss: 0.9713 - val_accuracy: 0.6838
# Fin de l'entraînement du modèle pour data_1.
#
# Entraînement du modèle pour data_2 :
# Epoch 1/8
# 87/87 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.7135
# Epoch 1: val_accuracy improved from 0.68378 to 0.73289, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 931s 11s/step - loss: 0.9260 - accuracy: 0.7135 - val_loss: 0.8974 - val_accuracy: 0.7329
# Epoch 2/8
# 87/87 [==============================] - ETA: 0s - loss: 0.8704 - accuracy: 0.7300
# Epoch 2: val_accuracy improved from 0.73289 to 0.75521, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 923s 11s/step - loss: 0.8704 - accuracy: 0.7300 - val_loss: 0.8342 - val_accuracy: 0.7552
# Epoch 3/8
# 87/87 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.7446
# Epoch 3: val_accuracy did not improve from 0.75521
# 87/87 [==============================] - 922s 11s/step - loss: 0.8235 - accuracy: 0.7446 - val_loss: 0.8175 - val_accuracy: 0.7522
# Epoch 4/8
# 87/87 [==============================] - ETA: 0s - loss: 0.7861 - accuracy: 0.7581
# Epoch 4: val_accuracy improved from 0.75521 to 0.75967, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 934s 11s/step - loss: 0.7861 - accuracy: 0.7581 - val_loss: 0.7954 - val_accuracy: 0.7597
# Epoch 5/8
# 87/87 [==============================] - ETA: 0s - loss: 0.7589 - accuracy: 0.7653
# Epoch 5: val_accuracy improved from 0.75967 to 0.76190, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 924s 11s/step - loss: 0.7589 - accuracy: 0.7653 - val_loss: 0.7871 - val_accuracy: 0.7619
# Epoch 6/8
# 87/87 [==============================] - ETA: 0s - loss: 0.7281 - accuracy: 0.7763
# Epoch 6: val_accuracy did not improve from 0.76190
# 87/87 [==============================] - 931s 11s/step - loss: 0.7281 - accuracy: 0.7763 - val_loss: 0.7360 - val_accuracy: 0.7619
# Epoch 7/8
# 87/87 [==============================] - ETA: 0s - loss: 0.7013 - accuracy: 0.7818
# Epoch 7: val_accuracy improved from 0.76190 to 0.79315, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 925s 11s/step - loss: 0.7013 - accuracy: 0.7818 - val_loss: 0.6954 - val_accuracy: 0.7932
# Epoch 8/8
# 87/87 [==============================] - ETA: 0s - loss: 0.6762 - accuracy: 0.7942
# Epoch 8: val_accuracy did not improve from 0.79315
# 87/87 [==============================] - 929s 11s/step - loss: 0.6762 - accuracy: 0.7942 - val_loss: 0.6783 - val_accuracy: 0.7909
# Fin de l'entraînement du modèle pour data_2.
#
# Entraînement du modèle pour data_3 :
# Epoch 1/8
# 87/87 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.7867
# Epoch 1: val_accuracy did not improve from 0.79315
# 87/87 [==============================] - 939s 11s/step - loss: 0.6797 - accuracy: 0.7867 - val_loss: 0.6796 - val_accuracy: 0.7775
# Epoch 2/8
# 87/87 [==============================] - ETA: 0s - loss: 0.6579 - accuracy: 0.7908
# Epoch 2: val_accuracy improved from 0.79315 to 0.80060, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 927s 11s/step - loss: 0.6579 - accuracy: 0.7908 - val_loss: 0.6281 - val_accuracy: 0.8006
# Epoch 3/8
# 87/87 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.8000
# Epoch 3: val_accuracy improved from 0.80060 to 0.80208, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 931s 11s/step - loss: 0.6326 - accuracy: 0.8000 - val_loss: 0.6348 - val_accuracy: 0.8021
# Epoch 4/8
# 87/87 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.8056
# Epoch 4: val_accuracy did not improve from 0.80208
# 87/87 [==============================] - 936s 11s/step - loss: 0.6177 - accuracy: 0.8056 - val_loss: 0.6146 - val_accuracy: 0.8013
# Epoch 5/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.8122
# Epoch 5: val_accuracy improved from 0.80208 to 0.80580, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 931s 11s/step - loss: 0.5977 - accuracy: 0.8122 - val_loss: 0.6030 - val_accuracy: 0.8058
# Epoch 6/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.8189
# Epoch 6: val_accuracy improved from 0.80580 to 0.80655, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 935s 11s/step - loss: 0.5835 - accuracy: 0.8189 - val_loss: 0.6004 - val_accuracy: 0.8065
# Epoch 7/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5694 - accuracy: 0.8216
# Epoch 7: val_accuracy improved from 0.80655 to 0.81771, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 937s 11s/step - loss: 0.5694 - accuracy: 0.8216 - val_loss: 0.5777 - val_accuracy: 0.8177
# Epoch 8/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.8243
# Epoch 8: val_accuracy did not improve from 0.81771
# 87/87 [==============================] - 930s 11s/step - loss: 0.5550 - accuracy: 0.8243 - val_loss: 0.5676 - val_accuracy: 0.8155
# Fin de l'entraînement du modèle pour data_3.
#
# Entraînement du modèle pour data_4 :
# Epoch 1/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.8228
# Epoch 1: val_accuracy improved from 0.81771 to 0.82589, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 927s 11s/step - loss: 0.5833 - accuracy: 0.8228 - val_loss: 0.5579 - val_accuracy: 0.8259
# Epoch 2/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5721 - accuracy: 0.8255
# Epoch 2: val_accuracy improved from 0.82589 to 0.83333, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 940s 11s/step - loss: 0.5721 - accuracy: 0.8255 - val_loss: 0.5512 - val_accuracy: 0.8333
# Epoch 3/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5531 - accuracy: 0.8302
# Epoch 3: val_accuracy did not improve from 0.83333
# 87/87 [==============================] - 933s 11s/step - loss: 0.5531 - accuracy: 0.8302 - val_loss: 0.5345 - val_accuracy: 0.8311
# Epoch 4/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.8356
# Epoch 4: val_accuracy did not improve from 0.83333
# 87/87 [==============================] - 934s 11s/step - loss: 0.5389 - accuracy: 0.8356 - val_loss: 0.5381 - val_accuracy: 0.8274
# Epoch 5/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.8403
# Epoch 5: val_accuracy improved from 0.83333 to 0.83408, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 938s 11s/step - loss: 0.5287 - accuracy: 0.8403 - val_loss: 0.5291 - val_accuracy: 0.8341
# Epoch 6/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.8453
# Epoch 6: val_accuracy did not improve from 0.83408
# 87/87 [==============================] - 932s 11s/step - loss: 0.5141 - accuracy: 0.8453 - val_loss: 0.5235 - val_accuracy: 0.8318
# Epoch 7/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5021 - accuracy: 0.8437
# Epoch 7: val_accuracy improved from 0.83408 to 0.83482, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 930s 11s/step - loss: 0.5021 - accuracy: 0.8437 - val_loss: 0.5304 - val_accuracy: 0.8348
# Epoch 8/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5010 - accuracy: 0.8455
# Epoch 8: val_accuracy improved from 0.83482 to 0.83780, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 944s 11s/step - loss: 0.5010 - accuracy: 0.8455 - val_loss: 0.5160 - val_accuracy: 0.8378
# Fin de l'entraînement du modèle pour data_4.
#
# Entraînement du modèle pour data_5 :
# Epoch 1/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.8273
# Epoch 1: val_accuracy improved from 0.83780 to 0.84598, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 931s 11s/step - loss: 0.5301 - accuracy: 0.8273 - val_loss: 0.4939 - val_accuracy: 0.8460
# Epoch 2/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.8295
# Epoch 2: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 930s 11s/step - loss: 0.5163 - accuracy: 0.8295 - val_loss: 0.5105 - val_accuracy: 0.8326
# Epoch 3/8
# 87/87 [==============================] - ETA: 0s - loss: 0.5037 - accuracy: 0.8374
# Epoch 3: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 929s 11s/step - loss: 0.5037 - accuracy: 0.8374 - val_loss: 0.5054 - val_accuracy: 0.8430
# Epoch 4/8
# 87/87 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.8353
# Epoch 4: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 934s 11s/step - loss: 0.4955 - accuracy: 0.8353 - val_loss: 0.4931 - val_accuracy: 0.8363
# Epoch 5/8
# 87/87 [==============================] - ETA: 0s - loss: 0.4825 - accuracy: 0.8401
# Epoch 5: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 928s 11s/step - loss: 0.4825 - accuracy: 0.8401 - val_loss: 0.4844 - val_accuracy: 0.8415
# Epoch 6/8
# 87/87 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.8448
# Epoch 6: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 933s 11s/step - loss: 0.4807 - accuracy: 0.8448 - val_loss: 0.4724 - val_accuracy: 0.8452
# Epoch 7/8
# 87/87 [==============================] - ETA: 0s - loss: 0.4628 - accuracy: 0.8558
# Epoch 7: val_accuracy did not improve from 0.84598
# 87/87 [==============================] - 929s 11s/step - loss: 0.4628 - accuracy: 0.8558 - val_loss: 0.4881 - val_accuracy: 0.8348
# Epoch 8/8
# 87/87 [==============================] - ETA: 0s - loss: 0.4532 - accuracy: 0.8541
# Epoch 8: val_accuracy improved from 0.84598 to 0.84970, saving model to tf_VGG16_id_nom_maladie.h5
# 87/87 [==============================] - 943s 11s/step - loss: 0.4532 - accuracy: 0.8541 - val_loss: 0.4879 - val_accuracy: 0.8497
# Fin de l'entraînement du modèle pour data_5.

# %%
# Visualisation de l'accuracy du train et de la validation
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy du modèle')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Visualisation de la loss du train et de la validation
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss du modèle')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Sauvegarde du modèle

# %%
# Chargement du modèle

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))


for layer in base_model.layers:
    layer.trainable = False


x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
predictions = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.models.Model(inputs=base_model.input, outputs=predictions)

model.load_weights('tf_VGG16_id_nom_maladie.h5')

# Compilation 

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Sauvegarde du modèle

model.save('model_tf_VGG16_id_nom_maladie_no_bg.h5')
